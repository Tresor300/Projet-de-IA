# %%
import pandas as pd

# Chargement du jeu de données brut
df_brut = pd.read_csv('export_IA.csv')

# Affichage de toutes les colonnes disponibles
print("Liste des colonnes :")
print(df_brut.columns.tolist())
# Out:
# Liste des colonnes :
# ['contact_operateur', 'nom_enseigne', 'id_station_itinerance', 'nom_station', 'implantation_station', 'adresse_station', 'coordonneesXY', 'nbre_pdc', 'id_pdc_itinerance', 'puissance_nominale', 'prise_type_ef', 'prise_type_2', 'prise_type_combo_ccs', 'prise_type_chademo', 'prise_type_autre', 'paiement_acte', 'tarification', 'condition_acces', 'reservation', 'horaires', 'accessibilite_pmr', 'restriction_gabarit', 'station_deux_roues', 'date_maj', 'last_modified', 'datagouv_dataset_id', 'datagouv_resource_id', 'datagouv_organization_or_owner', 'created_at', 'consolidated_longitude', 'consolidated_latitude', 'consolidated_code_postal', 'consolidated_commune', 'consolidated_is_lon_lat_correct', 'consolidated_is_code_insee_verified', 'consolidated_is_code_insee_modified']

# %%
import pandas as pd

# Chargement du jeu de données brut
df_brut = pd.read_csv('export_IA.csv')

# Affichage de toutes les colonnes disponibles
print(df_brut.columns.tolist())
# Out:
# ['contact_operateur', 'nom_enseigne', 'id_station_itinerance', 'nom_station', 'implantation_station', 'adresse_station', 'coordonneesXY', 'nbre_pdc', 'id_pdc_itinerance', 'puissance_nominale', 'prise_type_ef', 'prise_type_2', 'prise_type_combo_ccs', 'prise_type_chademo', 'prise_type_autre', 'paiement_acte', 'tarification', 'condition_acces', 'reservation', 'horaires', 'accessibilite_pmr', 'restriction_gabarit', 'station_deux_roues', 'date_maj', 'last_modified', 'datagouv_dataset_id', 'datagouv_resource_id', 'datagouv_organization_or_owner', 'created_at', 'consolidated_longitude', 'consolidated_latitude', 'consolidated_code_postal', 'consolidated_commune', 'consolidated_is_lon_lat_correct', 'consolidated_is_code_insee_verified', 'consolidated_is_code_insee_modified']

# %%
# Sélection des colonnes exactes trouvées dans votre fichier
colonnes_utiles = [
    'consolidated_latitude', 
    'consolidated_longitude', 
    'implantation_station', 
    'puissance_nominale'
]

# Création du DataFrame dédié au Besoin 1
df_besoin1 = df_brut[colonnes_utiles].copy()

# Affichage des premières lignes pour vérifier que l'extraction a fonctionné
print("--- Aperçu du nouveau tableau filtré ---")
print(df_besoin1.head())

# Vérification critique : y a-t-il des données manquantes dans ces 4 colonnes ?
print("\n--- Décompte des valeurs nulles (NaN) ---")
print(df_besoin1.isnull().sum())
# Out:
# --- Aperçu du nouveau tableau filtré ---
#    consolidated_latitude  consolidated_longitude  \
# 0              43.792972                0.628264
# 1              43.539773                1.512599
# 2              48.927684                3.130455
# 3              47.348015                0.647692
# 4              47.348060                0.647698
#
#            implantation_station  puissance_nominale
# 0                Parking public              150.00
# 1  Parking privé à usage public              150.00
# 2                        Voirie               22.08
# 3  Parking privé à usage public              150.00
# 4  Parking privé à usage public              150.00
#
# --- Décompte des valeurs nulles (NaN) ---
# consolidated_latitude     0
# consolidated_longitude    0
# implantation_station      0
# puissance_nominale        0
# dtype: int64

# %%
# %pip install nbformat
# Out:
# Requirement already satisfied: nbformat in c:\Users\PC\anaconda3\envs\projet_ia\Lib\site-packages (5.10.4)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\Users\PC\anaconda3\envs\projet_ia\Lib\site-packages (from nbformat) (2.21.2)
# Requirement already satisfied: jsonschema>=2.6 in c:\Users\PC\anaconda3\envs\projet_ia\Lib\site-packages (from nbformat) (4.26.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\Users\PC\anaconda3\envs\projet_ia\Lib\site-packages (from nbformat) (5.9.1)
# Requirement already satisfied: traitlets>=5.1 in c:\Users\PC\anaconda3\envs\projet_ia\Lib\site-packages (from nbformat) (5.15.0)
# Requirement already satisfied: attrs>=22.2.0 in c:\Users\PC\anaconda3\envs\projet_ia\Lib\site-packages (from jsonschema>=2.6->nbformat) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\Users\PC\anaconda3\envs\projet_ia\Lib\site-packages (from jsonschema>=2.6->nbformat) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\Users\PC\anaconda3\envs\projet_ia\Lib\site-packages (from jsonschema>=2.6->nbformat) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in c:\Users\PC\anaconda3\envs\projet_ia\Lib\site-packages (from jsonschema>=2.6->nbformat) (2026.5.1)
# Requirement already satisfied: platformdirs>=2.5 in c:\Users\PC\anaconda3\envs\projet_ia\Lib\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat) (4.9.4)
# Requirement already satisfied: typing-extensions>=4.4.0 in c:\Users\PC\anaconda3\envs\projet_ia\Lib\site-packages (from referencing>=0.28.4->jsonschema>=2.6->nbformat) (4.15.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import plotly.express as px
import plotly.io as pio

# LA SOLUTION : On force Plotly à contourner VS Code et à utiliser le navigateur web
pio.renderers.default = "browser"

# 1. Graphique de la répartition des types d'implantation
fig_impl = px.histogram(
    df_besoin1, 
    x='implantation_station', 
    color='implantation_station',
    title="Répartition des bornes par type d'implantation",
    labels={'implantation_station': "Type d'implantation"},
    text_auto=True
)
fig_impl.update_layout(xaxis_categoryorder='total descending')
fig_impl.show() # Cela va ouvrir un nouvel onglet dans votre navigateur

# 2. Graphique de la distribution des puissances nominales
fig_puiss = px.histogram(
    df_besoin1, 
    x='puissance_nominale', 
    title="Distribution de la puissance nominale (en kW)",
    nbins=50,
    labels={'puissance_nominale': 'Puissance Nominale (kW)'}
)
fig_puiss.show() # Cela va ouvrir un deuxième onglet
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 13
#       9     labels={'implantation_station': "Type d'implantation"},
#      10     text_auto=True # Affiche le compte exact sur les barres
#      11 )
#      12 fig_impl.update_layout(xaxis_categoryorder='total descending') # Trie du plus grand au plus petit
# ---> 13 fig_impl.show()
#      14
#      15 # 2. Graphique de la distribution des puissances nominales
#      16 fig_puiss = px.histogram(
#
# File c:\Users\PC\anaconda3\envs\projet_ia\Lib\site-packages\plotly\basedatatypes.py:3420, in BaseFigure.show(self, *args, **kwargs)
#    3387 """
#    3388 Show a figure using either the default renderer(s) or the renderer(s)
#    3389 specified by the renderer argument
#    (...)   3416 None
#    3417 """
#    3418 import plotly.io as pio
# -> 3420 return pio.show(self, *args, **kwargs)
#
# File c:\Users\PC\anaconda3\envs\projet_ia\Lib\site-packages\plotly\io\_renderers.py:415, in show(fig, renderer, validate, **kwargs)
#     410     raise ValueError(
#     411         "Mime type rendering requires ipython but it is not installed"
#     412     )
#     414 if not nbformat or Version(nbformat.__version__) < Version("4.2.0"):
# --> 415     raise ValueError(
#     416         "Mime type rendering requires nbformat>=4.2.0 but it is not installed"
#     417     )
#     419 display_jupyter_version_warnings()
#     421 ipython_display.display(bundle, raw=True)
#
# ValueError: Mime type rendering requires nbformat>=4.2.0 but it is not installed
